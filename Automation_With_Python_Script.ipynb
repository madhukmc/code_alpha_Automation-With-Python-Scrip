# %% [markdown]
# <a href="https://colab.research.google.com/github/madhukmc/code_alpha_Automation-With-Python-Scrip/blob/main/Automation_With_Python_Script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Automation With Python Script

# %%
file1=open('sample.txt','w')
file1.writelines(["reddybrami239@gmail.com","ramireddyit5@gmail.com"])
file1.close()
import re
input_file = "sample.txt"
output_file = "output.txt"
with open(input_file,'r',encoding='utf-8') as file:
  text=file.read()
emails=re.findall(r'[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}', text)
with open(output_file,'w',encoding='utf-8') as f:
  f.write('\n'.join(emails) + '\n')
print(f"extracted{len(set(emails))} emaail addresses and saved to '{output_file}'")
# Out:
# extracted2 emaail addresses and saved to 'output.txt'
